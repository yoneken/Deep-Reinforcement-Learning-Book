# %% [markdown]
# # uFactory xArm6
#
# https://www.ufactory.us/product/ufactory-xarm-6

# %%
import sys, os
from xarm.wrapper import XArmAPI

# %% [markdown]
# ## テスト

# %%
arm = XArmAPI("192.168.0.244", is_radian=True)

if arm.warn_code != 0:
    arm.clean_warn()
if arm.error_code != 0:
    arm.clean_error()
    
arm.motion_enable(enable=True)
arm.set_mode(0)
arm.set_state(state=0)
# Out:
# ROBOT_IP: 192.168.0.244, VERSION: v2.6.0, PROTOCOL: V1, DETAIL: 6,6,XI1100,XX0000,v2.6.0, TYPE1300: [0, 0]
# change protocol identifier to 3
# ControllerError, code: 1
# servo_error_code, servo_id=1, status=3, code=0
# ControllerError had clean
# servo_error_code, servo_id=1, status=0, code=0
# [motion_enable], xArm is not ready to move
# [set_state], xArm is ready to move
# 0
# ControllerError, code: 1

# %%
arm.set_position(x=360, y=0, z=370, roll=120, pitch=-90, yaw=60, speed=400, is_radian=False, wait=True)
print(arm.get_position(), arm.get_position(is_radian=False))
arm.set_position(x=360, y=240, z=370, roll=120, pitch=-90, yaw=60, speed=400, is_radian=False, wait=True)
print(arm.get_position(), arm.get_position(is_radian=False))
arm.set_position(x=360, y=-240, z=370, roll=120, pitch=-90, yaw=60, speed=400, is_radian=False, wait=True)
print(arm.get_position(), arm.get_position(is_radian=False))
arm.set_position(x=360, y=240, z=370, roll=120, pitch=-90, yaw=60, speed=400, is_radian=False, wait=True)
print(arm.get_position(), arm.get_position(is_radian=False))
arm.set_position(x=360, y=-240, z=370, roll=120, pitch=-90, yaw=60, speed=400, is_radian=False, wait=True)
print(arm.get_position(), arm.get_position(is_radian=False))
arm.set_position(x=360, y=240, z=370, roll=120, pitch=-90, yaw=60, speed=400, is_radian=False, wait=True)
print(arm.get_position(), arm.get_position(is_radian=False))
arm.set_position(x=360, y=-240, z=370, roll=120, pitch=-90, yaw=60, speed=400, is_radian=False, wait=True)
print(arm.get_position(), arm.get_position(is_radian=False))

arm.disconnect()
# Out:
# (0, [360.0, -7.4e-05, 370.0, 3.141593, -1.570796, 0.0]) (0, [360.0, -7.4e-05, 370.0, 180.00002, -89.999981, 0.0])
# (0, [360.0, 239.999924, 370.0, -3.141593, -1.570796, 0.0]) (0, [360.0, 239.999924, 370.0, -180.00002, -89.999981, 0.0])
# (0, [360.0, -239.999924, 370.0, -3.141593, -1.570796, 0.0]) (0, [360.0, -239.999924, 370.0, -180.00002, -89.999981, 0.0])
# (0, [360.0, 239.999924, 370.0, -3.141593, -1.570796, 0.0]) (0, [360.0, 239.999924, 370.0, -180.00002, -89.999981, 0.0])
# (0, [360.0, -239.999924, 370.0, -3.141593, -1.570796, 0.0]) (0, [360.0, -239.999924, 370.0, -180.00002, -89.999981, 0.0])
# (0, [360.0, 239.999924, 370.0, -3.141593, -1.570796, 0.0]) (0, [360.0, 239.999924, 370.0, -180.00002, -89.999981, 0.0])
# (0, [360.0, -239.999924, 370.0, -3.141593, -1.570796, 0.0]) (0, [360.0, -239.999924, 370.0, -180.00002, -89.999981, 0.0])
# [SDK][ERROR][2025-10-04 10:46:27][base.py:293] - - [main-socket] recv error: [WinError 10054] 既存の接続はリモート ホストに強制的に切断されました。
# [SDK][ERROR][2025-10-04 10:46:27][base.py:247] - - [report-socket] recv error: [WinError 10054] 既存の接続はリモート ホストに強制的に切断されました。
# [SDK][ERROR][2025-10-04 10:46:27][base.py:247] - - [report-socket] recv error: [WinError 10054] 既存の接続はリモート ホストに強制的に切断されました。
# [SDK][ERROR][2025-10-04 10:46:27][base.py:293] - - [main-socket] recv error: [WinError 10054] 既存の接続はリモート ホストに強制的に切断されました。
# [SDK][ERROR][2025-10-04 10:46:27][base.py:247] - - [report-socket] recv error: [WinError 10054] 既存の接続はリモート ホストに強制的に切断されました。
# [SDK][ERROR][2025-10-04 10:46:27][base.py:293] - - [main-socket] recv error: [WinError 10054] 既存の接続はリモート ホストに強制的に切断されました。
# [SDK][ERROR][2025-10-04 10:46:27][base.py:247] - - [report-socket] recv error: [WinError 10054] 既存の接続はリモート ホストに強制的に切断されました。
# [SDK][ERROR][2025-10-04 10:46:27][base.py:293] - - [main-socket] recv error: [WinError 10054] 既存の接続はリモート ホストに強制的に切断されました。

# %%
# Move to Y min
arm.set_position(x=360, y=240, z=370, roll=120, pitch=-90, yaw=60, speed=400, is_radian=False, wait=True)
print(arm.get_position(), arm.get_position(is_radian=False))

# realsense: x=0.235m, y=0.042m, z=0.554m
# Out:
# (0, [360.0, 239.999924, 370.0, -3.141593, -1.570796, 0.0]) (0, [360.0, 239.999924, 370.0, -180.00002, -89.999981, 0.0])

# %%
# Move to Y max
arm.set_position(x=360, y=-240, z=370, roll=120, pitch=-90, yaw=60, speed=400, is_radian=False, wait=True)
print(arm.get_position(), arm.get_position(is_radian=False))

# realsense: x=-0.232m, y=0.052m, z=0.547m
# Out:
# (0, [360.0, -239.999924, 370.0, -3.141593, -1.570796, 0.0]) (0, [360.0, -239.999924, 370.0, -180.00002, -89.999981, 0.0])
# [SDK][ERROR][2025-10-04 14:35:22][base.py:293] - - [main-socket] recv error: [WinError 10054] 既存の接続はリモート ホストに強制的に切断されました。
# [SDK][ERROR][2025-10-04 14:35:22][base.py:247] - - [report-socket] recv error: [WinError 10054] 既存の接続はリモート ホストに強制的に切断されました。
